# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import cv2

import torch
import torch.nn.functional as F
from torch import nn, optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, Dataset
from torchmetrics.functional.detection.iou import intersection_over_union
from ultralytics import YOLO

# %%
device = ('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# 'cuda'

# %%
# image_path = ''
# image = cv2.imread(image_path)
# original = image.copy()
# results = model_v(image)

# for result in results:
#     cls = int(box.cls.item())
#     conf = box.conf.item()
#     xyxy = box.xyxy.tolist()[0]

#     if cls == 0 and conf > 0.5:
#         x1, y1, x2, y2 = map(int, xyxy)

#         face_region = image[y1:y2, x1:x2]
#         blur = cv2.GaussianBlur(face_region, (99, 99), 30)
#         image[y1:y2, x1:x2] = blur

# %%
# model = YOLO('yolov8n.pt')
# model.train(data = '/home/selendis/bootcamp/project_yolo/data.yaml',
#             epochs = 10,
#             imgsz = 640,
#             batch =  8,
#             degrees=10.0,
#             hsv_s= 0.9,
#         #    augment=True,
#        #     translate=0.1 не очень
#             name = 'faces')
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 3769MiB)
# ...

# %%
model = YOLO('/home/selendis/bootcamp/ds-phase-2/runs/detect/faces9_yolov8/weights/best.pt')
metrics = model.val(data='/home/selendis/bootcamp/project_yolo/data.yaml')
# Out:
# Ultralytics 8.3.241 🚀 Python-3.12.12 torch-2.7.1+cu118 CUDA:0 (NVIDIA GeForce RTX 2050, 3769MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 285.5±199.2 MB/s, size: 119.6 KB)
# val: Scanning /home/selendis/bootcamp/project_yolo/labels/val.cache... 3347 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3347/3347 8.7Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 210/210 9.7it/s 21.7ss<0.1s
#                    all       3347      10299      0.901      0.805       0.88      0.587
# Speed: 0.4ms preprocess, 4.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to /home/selendis/bootcamp/ds-phase-2/runs/detect/val

# %%
print("Precision:", metrics.box.mp)    # mean precision
print("Recall:", metrics.box.mr)       # mean recall
print("mAP50:", metrics.box.map50)     # mAP at IoU=0.5
print("mAP50-95:", metrics.box.map)    # mAP across IoU thresholds 0.5:0.95
print("F1-score (по классам):", metrics.box.f1)  # массив F1-оценок по каждому классу
print("Confusion matrix:\n", metrics.box.confusion_matrix)
# Out:
# Precision: 0.9011393178383017
# Recall: 0.8053209049422274
# mAP50: 0.8803413329675661
# mAP50-95: 0.5871420000257818
# F1-score (по классам): [    0.85054]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 6
#       4 print("mAP50-95:", metrics.box.map)    # mAP across IoU thresholds 0.5:0.95
#       5 print("F1-score (по классам):", metrics.box.f1)  # массив F1-оценок по каждому классу
# ----> 6 print("Confusion matrix:\n", metrics.box.confusion_matrix)
#
# File ~/bootcamp/project_yolo/venv/lib/python3.12/site-packages/ultralytics/utils/__init__.py:279, in SimpleClass.__getattr__(self, attr)
#     277 """Provide a custom attribute access error message with helpful information."""
#     278 name = self.__class__.__name__
# --> 279 raise AttributeError(f"'{name}' object has no attribute '{attr}'. See valid attributes below.\n{self.__doc__}")
#
# ...
